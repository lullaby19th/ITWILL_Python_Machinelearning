# %% [markdown]
# ## ■ 13장. 회귀분석
#
# 회귀분석은 하나의 변수가 나머지 다른 변수들과의 선형적 관계를 갖는가의 여부를 분석하는 방법으로
# 하나의 종속변수(예측하고자 하는 값)와 독립변수 사이의 관계를 명시하는것을 말합니다.
#
# __예: 집값에 가장 영향을 주는 요소가 무엇인가?__
#
# - 독립변수 : 종속변수에 영향을 주는 변수들 (평수, 역세권, ..)
# - 종속변수 : 서로 관계를 가지고 잇는 변수들 중에서 다른 변수에 영향을 받는 변수 (집값)
#
# 사진 --> 보스톤 탬즈강
#
# ### ※ 회귀식 : y = ax + b
#
# 기울기를 구하기 위해서 사용하는 방법 ? 최소제곱 추정법

# %% [markdown]
# ## ■ 단순 회귀분석 파이썬 예제1
#
# __" 탄닌 함유량과 애벌레 성장간의 관계 "__
#
# 애벌레의 사료에 탄닌(영양제)의 양에 따라 애벌레의 성장률이 어떻게 되는지 조사하려 한다.
# 맛이 없어서 잘 안먹어서 성장이 떨어지는 겨로가가 나타남.

# %%
import statsmodels.api as sm
import statsmodels.formula.api as smf
import pandas as pd

df = pd.read_csv("d:\\data\\bug\\regression.csv", engine = 'python', encoding = 'cp949')
print(df)
# growth = 종속변수
# tannin = 독립변수

model = smf.ols(formula = 'growth ~ tannin', data = df)
result = model.fit()
print(result.summary()) # 이러면 회귀분석 결과 나옴
# Out:
#    growth  tannin
# 0      12       0
# 1      10       1
# 2       8       2
# 3      11       3
# 4       6       4
# 5       7       5
# 6       2       6
# 7       3       7
# 8       3       8
#                             OLS Regression Results
# ...
# Dep. Variable:                 growth   R-squared:                       0.816
# Model:                            OLS   Adj. R-squared:                  0.789
# Method:                 Least Squares   F-statistic:                     30.97
# Date:                Tue, 11 Feb 2020   Prob (F-statistic):           0.000846
# Time:                        11:10:54   Log-Likelihood:                -16.380
# No. Observations:                   9   AIC:                             36.76
# Df Residuals:                       7   BIC:                             37.15
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ...

# %%
""""
OLS Regression Results                            
==============================================================================
Dep. Variable:                 growth   R-squared:                       0.816
Model:                            OLS   Adj. R-squared:                  0.789
Method:                 Least Squares   F-statistic:                     30.97
Date:                Tue, 11 Feb 2020   Prob (F-statistic):           0.000846
Time:                        11:10:54   Log-Likelihood:                -16.380
No. Observations:                   9   AIC:                             36.76
Df Residuals:                       7   BIC:                             37.15
Df Model:                           1                                         
Covariance Type:            nonrobust                                         
==============================================================================
                 coef          std err          t      P>|t|      [0.025      0.975]
------------------------------------------------------------------------------
Intercept     11.7556 (절편)    1.041     11.295      0.000       9.294      14.217
tannin        -1.2167 (기울기)  0.219     -5.565      0.001      -1.734      -0.700
==============================================================================
Omnibus:                        0.466   Durbin-Watson:                   2.937
Prob(Omnibus):                  0.792   Jarque-Bera (JB):                0.227
Skew:                           0.319   Prob(JB):                        0.893
Kurtosis:                       2.554   Cond. No.                         9.06
==============================================================================
"""

# 회귀식 : y = -1.2167 x + 11.7556

# %% [markdown]
# ## 문제217. 위의 애벌레 사료 데이터를 산포도 그래프로 시각화 하시오!
# ### (x축을 탄닌 함류량, y축을 성장률)

# %%
import statsmodels.api as sm
import statsmodels.formula.api as smf
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("d:\\data\\bug\\regression.csv", engine = 'python', encoding = 'cp949')

df.plot(kind = 'scatter', x = 'tannin', y = 'growth', c = 'red', s = 30, figsize=(10,5))
plt.show()
plt.close()

# %% [markdown]
# ## 문제218. 위의 산포도 그래프에 회귀직선을 그리시오!

# %%
import statsmodels.api as sm
import statsmodels.formula.api as smf
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("d:\\data\\bug\\regression.csv", engine = 'python', encoding = 'cp949')
sns.regplot(x = 'tannin', y = 'growth', color = 'red', data = df) # regplot(회귀 직선)
plt.show()
plt.close()

# %% [markdown]
# ## 문제219. 오전에 칠판에 그린 몸무게와 키와의 회귀직선의 방정식을 구하고 시각화 하시오!

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

weight = [72,72,70,43,48,54,51,52,73,45,60,62,64,47,51,74,88,64,56,56]
tall = [176,172,182,160,163,165,168,163,182,148,170,166,172,169,163,170,174,182,164,160]

dict_data = {'weight' : [72,72,70,43,48,54,51,52,73,45,60,62,64,47,51,74,88,64,56,56], 'tall' : [176,172,182,160,163,165,168,163,182,148,170,166,172,169,163,170,174,182,164,160]} 

df = pd.DataFrame(dict_data)

model = smf.ols(formula = 'tall ~ weight', data = df)
result = model.fit()
print(result.summary()) # 이러면 회귀분석 결과 나옴

sns.regplot(x = 'weight', y = 'tall', color = 'red', data = df) # regplot(회귀 직선)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                   tall   R-squared:                       0.508
# Model:                            OLS   Adj. R-squared:                  0.481
# Method:                 Least Squares   F-statistic:                     18.61
# Date:                Tue, 11 Feb 2020   Prob (F-statistic):           0.000418
# Time:                        14:13:41   Log-Likelihood:                -63.452
# No. Observations:                  20   AIC:                             130.9
# Df Residuals:                      18   BIC:                             132.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    138.0386      7.180     19.225      0.000     122.954     153.124
# ...

# %% [markdown]
# ## ■ 다항 회귀분석
#
# 앞에서 살펴본 단순 회귀분석은 두 변수간의 관계를 직선형태로 설명하는 알고리즘 입니다.
# 독립변수 x와 종속변수 y사이의 선형의 상관관계가 있지만,
# __직선 보다는 곡선으로 설명하는것이 적합할 때는 단순 회귀분석은 부적합합니다.__
# 이럴때 __다항 함수__를 사용하면 __복잡한 곡선형태의 회귀선__을 표현 할 수 있습니다.

# %%
# 1. 단순 회귀 분석 예제 
# simple_linear_regression.py
# -*- coding: utf-8 -*-

### 기본 라이브러리 불러오기
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

'''
[Step 1] 데이터 준비 - read_csv() 함수로 자동차 연비 데이터셋 가져오기
'''
# CSV 파일을 데이터프레임으로 변환
df = pd.read_csv('d:\\data\\pandas\\auto-mpg.csv', header=None)

# 열 이름 지정
df.columns = ['mpg','cylinders','displacement','horsepower','weight',
              'acceleration','model year','origin','name'] 

# 데이터 살펴보기
print(df.head())   
print('\n')

#  IPython 디스플레이 설정 - 출력할 열의 개수 한도 늘리기
pd.set_option('display.max_columns', 10)
print(df.head())   
print('\n')


'''
[Step 2] 데이터 탐색
'''

# 데이터 자료형 확인
print(df.info())  
print('\n')

# 데이터 통계 요약정보 확인
print(df.describe())
print('\n')

# horsepower 열의 자료형 변경 (문자열 ->숫자)
print(df['horsepower'].unique())          # horsepower 열의 고유값 확인
print('\n')

df['horsepower'].replace('?', np.nan, inplace=True)      # '?'을 np.nan으로 변경
df.dropna(subset=['horsepower'], axis=0, inplace=True)   # 누락데이터 행을 삭제
df['horsepower'] = df['horsepower'].astype('float')      # 문자열을 실수형으로 변환

print(df.describe())                                     # 데이터 통계 요약정보 확인
print('\n')


'''
[Step 3] 속성(feature 또는 variable) 선택
'''

# 분석에 활용할 열(속성)을 선택 (연비, 실린더, 출력, 중량)
ndf = df[['mpg', 'cylinders', 'horsepower', 'weight']]
print(ndf.head())   
print('\n')

### 종속 변수 Y인 "연비(mpg)"와 다른 변수 간의 선형관계를 그래프(산점도)로 확인
# Matplotlib으로 산점도 그리기
ndf.plot(kind='scatter', x='weight', y='mpg',  c='coral', s=10, figsize=(10, 5))
plt.show()
plt.close()

# seaborn으로 산점도 그리기
fig = plt.figure(figsize=(10, 5))   
ax1 = fig.add_subplot(1, 2, 1)
ax2 = fig.add_subplot(1, 2, 2)
sns.regplot(x='weight', y='mpg', data=ndf, ax=ax1)                 # 회귀선 표시
sns.regplot(x='weight', y='mpg', data=ndf, ax=ax2, fit_reg=False)  #회귀선 미표시 
plt.show()
plt.close()

# seaborn 조인트 그래프 - 산점도, 히스토그램
sns.jointplot(x='weight', y='mpg', data=ndf)              # 회귀선 없음
sns.jointplot(x='weight', y='mpg', kind='reg', data=ndf)  # 회귀선 표시
plt.show()

# seaborn pariplot으로 두 변수 간의 모든 경우의 수 그리기
sns.pairplot(ndf)  
plt.show()
plt.close()


'''
Step 4: 데이터셋 구분 - 훈련용(train data)/ 검증용(test data)
'''

# 속성(변수) 선택
X=ndf[['weight']]  #독립 변수 X
y=ndf['mpg']       #종속 변수 Y

# train data 와 test data로 구분(7:3 비율)
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,               #독립 변수 
                                                    y,               #종속 변수
                                                    test_size=0.3,   #검증 30%
                                                    random_state=10) #랜덤 추출 값 

print('train data 개수: ', len(X_train))
print('test data 개수: ', len(X_test))


'''
Step 5: 단순회귀분석 모형 - sklearn 사용
'''

# sklearn 라이브러리에서 선형회귀분석 모듈 가져오기
from sklearn.linear_model import LinearRegression

# 단순회귀분석 모형 객체 생성
lr = LinearRegression()   

# train data를 가지고 모형 학습
lr.fit(X_train, y_train)

# 학습을 마친 모형에 test data를 적용하여 결정계수(R-제곱) 계산
r_square = lr.score(X_test, y_test)
print(r_square)
print('\n')


# 회귀식의 기울기
print('기울기 a: ', lr.coef_)
print('\n')

# 회귀식의 y절편
print('y절편 b', lr.intercept_)
print('\n')

# 모형에 전체 X 데이터를 입력하여 예측한 값 y_hat을 실제 값 y와 비교 
y_hat = lr.predict(X)

plt.figure(figsize=(10, 5))
ax1 = sns.distplot(y, hist=False, label="y")
ax2 = sns.distplot(y_hat, hist=False, label="y_hat", ax=ax1)
plt.show()
plt.close()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0      130.0  3504.0          12.0          70
# 1  15.0          8         350.0      165.0  3693.0          11.5          70
# 2  18.0          8         318.0      150.0  3436.0          11.0          70
# 3  16.0          8         304.0      150.0  3433.0          12.0          70
# 4  17.0          8         302.0      140.0  3449.0          10.5          70
#
#    origin                       name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino
#
#
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0      130.0  3504.0          12.0          70
# 1  15.0          8         350.0      165.0  3693.0          11.5          70
# ...

# %% [markdown]
# ### ※ 결과
#
# 출력된 결과를 보면 실제 값은 왼쪽으로 편향되어 있고 예측값은 반대로 오른쪽으로 편중되는 경항을 보인다.
# 따라서 독립변수(weight)과 종속변수(mpg) 사이에 선형관계가 있지만, 모형의 오차를 더 줄일 필요가 있다.
# 앞에서 그린 산점도를 보면 직선보다는 곡선의 형태가 더 적합해 보인다.
# 이런 경우 비선형 회귀 분석을 통해 모형의 정확도를 높일 수 있다.

# %%
# 2. 다항 회귀 분석 예제
# polynomial_regression.py

# -*- coding: utf-8 -*-

### 기본 라이브러리 불러오기
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

'''
[Step 1 ~ 4] 데이터 준비 
'''
# CSV 파일을 데이터프레임으로 변환
df = pd.read_csv('d:\\data\\pandas\\auto-mpg.csv', header=None)

# 열 이름 지정
df.columns = ['mpg','cylinders','displacement','horsepower','weight',
              'acceleration','model year','origin','name'] 

# horsepower 열의 자료형 변경 (문자열 ->숫자)
df['horsepower'].replace('?', np.nan, inplace=True)      # '?'을 np.nan으로 변경
df.dropna(subset=['horsepower'], axis=0, inplace=True)   # 누락데이터 행을 삭제
df['horsepower'] = df['horsepower'].astype('float')      # 문자열을 실수형으로 변환

# 분석에 활용할 열(속성)을 선택 (연비, 실린더, 출력, 중량)
ndf = df[['mpg', 'cylinders', 'horsepower', 'weight']]

# ndf 데이터를 train data 와 test data로 구분(7:3 비율)
X=ndf[['weight']]  #독립 변수 X
y=ndf['mpg']     #종속 변수 Y

# train data 와 test data로 구분(7:3 비율)
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=10) 

print('훈련 데이터: ', X_train.shape)
print('검증 데이터: ', X_test.shape)   
print('\n')


'''
Step 5: 비선형회귀분석 모형 - sklearn 사용
'''

# sklearn 라이브러리에서 필요한 모듈 가져오기 
from sklearn.linear_model import LinearRegression      #선형회귀분석
from sklearn.preprocessing import PolynomialFeatures   #다항식 변환

# 다항식 변환 
poly = PolynomialFeatures(degree=2)               #2차항 적용
X_train_poly=poly.fit_transform(X_train)     #X_train 데이터를 2차항으로 변형

print('원 데이터: ', X_train.shape)
print('2차항 변환 데이터: ', X_train_poly.shape)  
print('\n')

# train data를 가지고 모형 학습
pr = LinearRegression()   
pr.fit(X_train_poly, y_train)

# 학습을 마친 모형에 test data를 적용하여 결정계수(R-제곱) 계산
X_test_poly = poly.fit_transform(X_test)       #X_test 데이터를 2차항으로 변형
r_square = pr.score(X_test_poly,y_test)
print(r_square)
print('\n')

# train data의 산점도와 test data로 예측한 회귀선을 그래프로 출력 
y_hat_test = pr.predict(X_test_poly)

fig = plt.figure(figsize=(10, 5))
ax = fig.add_subplot(1, 1, 1)
ax.plot(X_train, y_train, 'o', label='Train Data')  # 데이터 분포
ax.plot(X_test, y_hat_test, 'r+', label='Predicted Value') # 모형이 학습한 회귀선
ax.legend(loc='best')
plt.xlabel('weight')
plt.ylabel('mpg')
plt.show()
plt.close()

# 모형에 전체 X 데이터를 입력하여 예측한 값 y_hat을 실제 값 y와 비교 
X_ploy = poly.fit_transform(X)
y_hat = pr.predict(X_ploy)

plt.figure(figsize=(10, 5))
ax1 = sns.distplot(y, hist=False, label="y")
ax2 = sns.distplot(y_hat, hist=False, label="y_hat", ax=ax1)
plt.show()
plt.close()
# Out:
# 훈련 데이터:  (274, 1)
# 검증 데이터:  (118, 1)
#
#
# 원 데이터:  (274, 1)
# 2차항 변환 데이터:  (274, 3)
#
#
# 0.7087009262975479

# %% [markdown]
# ## 문제220.(점심시간 문제) 체중과 키와의 회귀 그래프를 다항 회귀분석 예제를 이용해서 비선형 그래프로 그리시오!

# %%
# 2. 다항 회귀 분석 예제
# polynomial_regression.py

# -*- coding: utf-8 -*-

### 기본 라이브러리 불러오기
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

'''
[Step 1 ~ 4] 데이터 준비 
'''
# CSV 파일을 데이터프레임으로 변환
weight = [72,72,70,43,48,54,51,52,73,45,60,62,64,47,51,74,88,64,56,56]
tall = [176,172,182,160,163,165,168,163,182,148,170,166,172,169,163,170,174,182,164,160]

dict_data = {'weight' : [72,72,70,43,48,54,51,52,73,45,60,62,64,47,51,74,88,64,56,56], 'tall' : [176,172,182,160,163,165,168,163,182,148,170,166,172,169,163,170,174,182,164,160]} 

df = pd.DataFrame(dict_data)
print(df.columns)

X=df[['weight']]  #독립 변수 X
y=df['tall']     #종속 변수 Y

'''
Step 5: 비선형회귀분석 모형 - sklearn 사용
'''

# sklearn 라이브러리에서 필요한 모듈 가져오기 
from sklearn.linear_model import LinearRegression      #선형회귀분석
from sklearn.preprocessing import PolynomialFeatures   #다항식 변환

# 다항식 변환 
poly = PolynomialFeatures(degree=2)               #2차항 적용
X_poly=poly.fit_transform(X)     
print('원 데이터: ', X.shape)
print('2차항 변환 데이터: ', X_poly.shape)  
print('\n')

# train data를 가지고 모형 학습
pr = LinearRegression()   
pr.fit(X_poly, y)

# 학습을 마친 모형에 test data를 적용하여 결정계수(R-제곱) 계산
X_test_poly = poly.fit_transform(X)       #X_test 데이터를 2차항으로 변형
r_square = pr.score(X_test_poly,y)
print(r_square)
print('\n')

# train data의 산점도와 test data로 예측한 회귀선을 그래프로 출력 
y_hat_test = pr.predict(X_test_poly)  

fig = plt.figure(figsize=(10, 5))
ax = fig.add_subplot(1, 1, 1)

ax.plot(X, y, 'o', label='Train Data')  # 데이터 분포
ax.plot(X, y_hat_test, 'r+', label='Predicted Value') # 모형이 학습한 회귀선
ax.legend(loc='best')
plt.xlabel('weight')
plt.ylabel('mpg')
plt.show()
plt.close()


# 모형에 전체 X 데이터를 입력하여 예측한 값 y_hat을 실제 값 y와 비교 
X_ploy = poly.fit_transform(X)
y_hat = pr.predict(X_ploy)

plt.figure(figsize=(10, 5))
ax1 = sns.distplot(y, hist=False, label="y")
ax2 = sns.distplot(y_hat, hist=False, label="y_hat", ax=ax1)
plt.show()
plt.close()
# Out:
# Index(['weight', 'tall'], dtype='object')
# 원 데이터:  (20, 1)
# 2차항 변환 데이터:  (20, 3)
#
#
# 0.5890555065346609

# %% [markdown]
# ## ■ 다중 회귀 분석
#
# 1. 단순회귀분석 : 독립변수 1개에 종속변수 1개(선형 회귀선)
# 2. 다항회귀분석 : 독립변수 1개에 종속변수 1개(비선형 회귀선)
# 3. 다중회귀분석 : 종속변수에 영향을 주는 독립변수가 여러개인 경우
#
# ### ※ 예제
#
# 1986년 1월 28일 미국의 스페이서 셔틀 첼린져호의 승무원 7명이 모두 사망을 했다.
# 우주 왕복선이 발사 도중에 폭파하는 바람에 사망을 했다.
# 원인분석을 하였더니 원인이???
#
# __" 발사 온도에 따른 O형링 파손이 원인이었다. "__
#
# - 종속변수 : O형링 파손수
# - 독립변수
#     1. 온도 : 온도가 낮으면 부품이 파손이 더 잘된다.
#     2. 압력 : 압력이 높으면 부품이 파손이 더 잘된다.
#     3. 비행기번호: 항공기가 오래될수록 부품들이 더 잘 부서지고 고장이 잘나는 경향이 있다.
#
# 위의 3가지 요소중에 O형링 파손에 가장 영향이 큰 것이 무엇인가?

# %%
import numpy as np
import statsmodels.api as sm
import statsmodels.formula.api as smf
import pandas as pd

df = pd.read_csv("d:\\data\\pandas\\challenger.csv", engine = 'python', encoding = 'cp949')
print(df)

model = smf.ols(formula = 'distress_ct ~ temperature + field_check_pressure + flight_num', data = df)
result = model.fit()
print(result.summary())
# Out:
#     distress_ct  temperature  field_check_pressure  flight_num
# 0             0           66                    50           1
# 1             1           70                    50           2
# 2             0           69                    50           3
# 3             0           68                    50           4
# 4             0           67                    50           5
# 5             0           72                    50           6
# 6             0           73                   100           7
# 7             0           70                   100           8
# 8             1           57                   200           9
# 9             1           63                   200          10
# 10            1           70                   200          11
# 11            0           78                   200          12
# 12            0           67                   200          13
# 13            2           53                   200          14
# ...

# %% [markdown]
# ### ※ 분석결과
#
# o형링 파손에 영향을 주는 __가장 큰 독립변수__는 __온도__이다.
# 그 다음이 비행기의 노후화를 나타내는 비행기 번호이다.
#
# __회귀식 :__ y = 3.5271 + -0.0514 * X1 + 0.0018 * X2 + 0.0143 * X3
#
# #### ※ 온도와 o형링 파손수를 나타내는 단순 회귀식을 도찰하면
#
# y = 3.70 - 0.048 * X1
# (y : 파손수, X1 : 온도)
#
# 2.21개 31도 F(화씨)
# 0.82개 60도 F(화씨)
# 0.34개 70도 F(화씨)
#
# 화씨 30도에서 발사하는게 화씨 60도에서 발사하는 것보다 3배 더 위험하고
# 화씨 70도에서 발사하는것보다 거의 7~8배 더 위험하다.

# %% [markdown]
# ### 문제221. 스마트폰 만족도(종속변수)에 영향을 미치는 요소중 가장 영향력이 있는 독립변수는 무엇인가?
#
# 1. 외관
# 2. 편의성
# 3. 유용성

# %%
import numpy as np
import statsmodels.api as sm
import statsmodels.formula.api as smf
import pandas as pd

df = pd.read_csv("d:\\data\\pandas\\multi_hg.csv", engine = 'python', encoding = 'cp949')
print(df)
print('\n\n')

model = smf.ols(formula = '만족감 ~ 외관 + 편의성 + 유용성', data = df)
result = model.fit()

print(result1.summary(), '\n')
# Out:
#          외관      편의성      유용성   만족감
# 0   0.92028  2.26322  2.49969  5.00
# 1   0.35472  0.11779  1.02933  3.00
# 2  -0.51868  0.20008 -0.28899  3.00
# 3   1.27550  0.16089  0.72871  4.33
# 4   1.25506 -1.83269  0.31254  3.33
# ..      ...      ...      ...   ...
# 75 -2.33923 -2.34202 -2.39260  1.33
# 76  0.92052  0.23808  0.67785  3.00
# 77 -2.27768 -1.14345 -0.34894  2.33
# 78  1.27371  0.33962  1.85597  5.00
# 79 -2.33923 -2.34202 -2.39260  1.33
#
# [80 rows x 4 columns]
#
#
#
#                             OLS Regression Results
# ...
# Dep. Variable:                    만족감   R-squared:                       0.373
# Model:                            OLS   Adj. R-squared:                  0.348
# Method:                 Least Squares   F-statistic:                     15.08
# Date:                Tue, 11 Feb 2020   Prob (F-statistic):           8.56e-08
# Time:                        14:26:51   Log-Likelihood:                -72.687
# ...

# %% [markdown]
# ### 문제222. 미국 대학교 입학에 가장 영향을 미치는 과목에 무엇인지 알아내시오~
#
# - 종속변수 : acceptance
# - 독립변수
#     1. academic
#     2. sports
#     3. music

# %%
import numpy as np
import statsmodels.api as sm
import statsmodels.formula.api as smf
import pandas as pd

df = pd.read_csv("d:\\data\\pandas\\sports.csv", engine = 'python', encoding = 'cp949')
print(df)
print('\n\n')
print(df.describe())
print('\n\n')

model = smf.ols(formula = 'acceptance ~ academic + sports + music', data = df)
result = model.fit()

print(result.summary(), '\n')
# Out:
#      Unnamed: 0  academic  sports      music  acceptance
# 0             1     230.1    37.8  62.909091   81.851852
# 1             2      44.5    39.3  41.000000   38.518519
# 2             3      17.2    45.9  63.000000   34.444444
# 3             4     151.5    41.3  68.518519   68.518519
# 4             5     180.8    10.8  53.090909   47.777778
# ..          ...       ...     ...        ...         ...
# 195         196      38.2     3.7  12.545455   28.148148
# 196         197      94.2     4.9   7.363636   35.925926
# 197         198     177.0     9.3   5.818182   47.407407
# 198         199     283.6    42.0  60.181818   94.444444
# 199         200     232.1     8.6   7.909091   49.629630
#
# [200 rows x 5 columns]
#
#
#
#        Unnamed: 0    academic      sports       music  acceptance
# count  200.000000  200.000000  200.000000  200.000000  200.000000
# mean   100.500000  147.042500   23.264000   40.311162   51.935185
# ...

# %% [markdown]
# ### 정규화를 안했을 때 --> sports가 academic 보다 더 영향력이 크다.
# ### 정규화를 했을 때 --> academic 이 sports보다 더 영향력이 크다
#
# 더 영향력 있는 독립변수를 알아내려면 정규화를 해야한다.
# 전부 0 ~ 1 사이의 데이터로 변경하고 독립변수의 영향도를 비교해야한다.
#
# 1. 회귀분석시 정규화를 해야하는 경우 ?
#     - 독립변수의 영향력을 확인할 때
#
#
# 2. 회귀분석시 정규화를 하지 말아야 하는 경우 ?
#     - 미국 의료비로 예를들면 남성이 여성에 비해 매년 의료비가 131.4달러 적게 든다는 것을 회귀분석 결과로 알아내려면 정규화하면 안된다.

# %%
# 정규화 하는 코드 sklearn 사용
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(data)
data = scaler.transform(data)
print(data)

# %%
import numpy as np
import statsmodels.api as sm
import statsmodels.formula.api as smf
import pandas as pd

data = pd.read_csv('d:\\data\\pandas\\sports2.csv', engine='python', encoding='CP949')

print(data.head())

from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(data)

data = scaler.transform(data)
print(data)


colname = ['stud_id','academic','sports','music','acceptance']

data_df = pd.DataFrame(data, columns=colname)



print(data_df.head())
print(data_df.columns.tolist()) # 컬럼목록을 list형태로 출력함.


del data_df['stud_id'] # 필요없는 'stud_id' 컬럼을 삭제한다.

print(data_df)


model = smf.ols(formula = 'acceptance ~ academic+sports+music', data = data_df)
result = model.fit()

print( result.summary() )
# Out:
#    1  230.1  37.8  62.9090909091  81.8518518519
# 0  2   44.5  39.3      41.000000      38.518519
# 1  3   17.2  45.9      63.000000      34.444444
# 2  4  151.5  41.3      68.518519      68.518519
# 3  5  180.8  10.8      53.090909      47.777778
# 4  6    8.7  48.9      68.181818      26.666667
# [[-1.72336879 -1.19233886  1.08765326  0.0287875  -0.69071733]
#  [-1.70596103 -1.51107385  1.53327319  0.81807989 -0.90283576]
#  [-1.68855326  0.0569155   1.2226896   1.01606738  0.87124572]
#  [-1.6711455   0.39900103 -0.8366146   0.46257216 -0.20862997]
#  [-1.65373773 -1.61031368  1.7358277   1.00398761 -1.30778915]
#  [-1.63632997 -1.04056029  0.64878515 -0.67570489 -0.4207484 ]
#  [-1.6189222  -0.30852059 -0.2424547  -1.06382801 -0.15077948]
#  [-1.60151443 -1.61148121 -1.42402268 -1.40955113 -1.77059301]
#  [-1.58410667  0.62083125 -1.39026359 -0.75072028 -0.65215034]
#  [-1.5666989  -0.94015293 -1.17420545 -0.65287412 -1.03782022]
# ...

# %% [markdown]
# ## ■ 회귀분석을 통한 의료비 예측
#
# 의료보험 회사가 돈을 벌려면 수익자에게 지출하는 의료비보다 연간 보험료를 더 많이 거수해야합니다.
# 그래서 보험회사는 피보험자 인구의 의료비를 정확히 예측하는 모델을 개발하기 위해 엄청난 시간과 비용을 투자하고 있습니다.
#
# 비용이 높은 질병은 대부분 희귀하고 랜덤하게 보이기 때문에 의료비 추정이 어렵다.
# 예를들어 폐암은 비흡연자보다 흡연자에게 발병할 가능성이 높고 심장질환은 비만인 사람들에게 더 발병할 가능성이 높다.
#
# 미국 통계국의 인구 통계를 이용한 의료비 데이터를 이용하겠습니다.
#
# #### 데이터 게시판 78. 보험 데이터
#
# - age : 나이
# - sex : 성별
# - bmi : 비만지수
# - children : 의료보험이 적용되는 부양 가족수
# - smoker : 흡연여부
# - region : 미국내 거주지역 (북도,북서,남동,남서)
# - expenses : 의료비

# %%
import pandas as pd

df = pd.read_csv("d:\\data\\pandas\\insurance.csv")
print(df.head())
# Out:
#    age     sex     bmi  children smoker     region     expenses
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %% [markdown]
# ## 문제223. expenses 를 시스토그램 그래프로 그려서 의료비의 분포를 확인하시오

# %%
import pandas as pd

insurance = pd.read_csv("d:\\data\\pandas\\insurance.csv")

tdf_ns = insurance['expenses'].T
print(tdf_ns
tdf_ns.plot(kind='hist')
# Out:
# 0       16884.92400
# 1        1725.55230
# 2        4449.46200
# 3       21984.47061
# 4        3866.85520
#            ...
# 1333    10600.54830
# 1334     2205.98080
# 1335     1629.83350
# 1336     2007.94500
# 1337    29141.36030
# Name: expenses, Length: 1338, dtype: float64

# %% [markdown]
# ### ※ 그래프 해석 : 대다수의 사람들의 연간 의료비는 0에서 $15,000 사이에 있음을 확인할 수 있다.

# %% [markdown]
# ## 문제224. 의료비 데이터에 결측치가 있는지 확인하시오!

# %%
import pandas as pd

df = pd.read_csv("d:\\data\\pandas\\insurance.csv")

print(df.isnull(), '\n\n')
print(df.isnull().sum())
# Out:
#         age    sex    bmi  children  smoker  region  expenses
# 0     False  False  False     False   False   False     False
# 1     False  False  False     False   False   False     False
# 2     False  False  False     False   False   False     False
# 3     False  False  False     False   False   False     False
# 4     False  False  False     False   False   False     False
# ...     ...    ...    ...       ...     ...     ...       ...
# 1333  False  False  False     False   False   False     False
# 1334  False  False  False     False   False   False     False
# 1335  False  False  False     False   False   False     False
# 1336  False  False  False     False   False   False     False
# 1337  False  False  False     False   False   False     False
#
# [1338 rows x 7 columns]
#
#
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# expenses    0
# dtype: int64

# %% [markdown]
# ### ※ 아나콘다 프롬프트 창을 연 후
#
# #### pip install quilt

# %% [markdown]
# ### 문제225. expenses를 종속변수로 하고 다른 변수들을 독립변수로 해서 다중회귀분석을 하시오!

# %%
import numpy as np
import statsmodels.api as sm
import statsmodels.formula.api as smf
import pandas as pd

df = pd.read_csv("d:\\data\\pandas\\insurance.csv", engine = 'python', encoding = 'cp949')
print(df)
print('\n\n')
print(df.describe())
print('\n\n')

model = smf.ols(formula = 'expenses ~ age + sex + bmi + smoker + region + children ', data = df)
# 다중회귀분석시 더미변수화(문자 -> 숫자) 가 자동으로 진행된다.

result = model.fit()

print(result.summary(), '\n')
# Out:
#       age     sex     bmi  children smoker     region     expenses
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]
#
#
#
#                age          bmi     children      expenses
# count  1338.000000  1338.000000  1338.000000   1338.000000
# ...

# %% [markdown]
# ### ※ 회귀분석 결과 해석
#
# 1. 남성은 여성에 비해 매년 의료비가 131.4 달러 적게 예상된다.
# 2. 흡연하는 사람은 비흡연자보다 매년 평균 의료바가 23,847 달러의 비용이 더든다.
# 3. 나이(age)가 일년씩 더해질 때마다 평균적으로 의료비가 256.8 달러 증가될 것으로 예상된다.
# 4. 비만지수(bmi)가 증가할 때마다 평균적으로 의료비가 339 달러가 증가될 것으로 예상된다.
# 5. 부양 가족수가 1명이 증가할 때마다 평균적으로 의료비가 475 달러가 증가될 것으로 예상된다.
# 6. 지역(region)은 북동지역(northeast) 기준으로 3개의 지역이 나와있는데, 지역별로 북동지역(northeast)에 비해
#     북서, 남동, 남서에 대한 의료비의 차이를 확인 할 수 있다.

# %% [markdown]
# ## ■ 결정계수(R-squared)가 무엇입니까?
#
# 결정계수는 회귀모형의 데이터에 대한 설명력을 나타내는 척도입니다.

# %% [markdown]
# ## 문제226. 나이가 증가하면 의료비가 증가되는지 파생변수를 추가해서 확인하시오!

# %%
# 추가해야할 코드

df['age2'] = df['age'] **2
model = smf.ols(formula = 'expenses ~ age + sex + bmi + smoker + region + children + age2', data = df)

# %%
import numpy as np
import statsmodels.api as sm
import statsmodels.formula.api as smf
import pandas as pd

df = pd.read_csv("d:\\data\\pandas\\insurance.csv", engine = 'python', encoding = 'cp949')
df['age2'] = df['age'] **2


model = smf.ols(formula = 'expenses ~ age + sex + bmi + smoker + region + children + age2', data = df)
# 다중회귀분석시 더미변수화(문자 -> 숫자) 가 자동으로 진행된다.

result = model.fit()

print(result.summary(), '\n')
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:               expenses   R-squared:                       0.754
# Model:                            OLS   Adj. R-squared:                  0.752
# Method:                 Least Squares   F-statistic:                     451.6
# Date:                Tue, 11 Feb 2020   Prob (F-statistic):               0.00
# Time:                        15:56:35   Log-Likelihood:                -13540.
# No. Observations:                1338   AIC:                         2.710e+04
# Df Residuals:                    1328   BIC:                         2.715e+04
# Df Model:                           9
# Covariance Type:            nonrobust
# ...
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# Intercept           -6596.6651   1689.444     -3.905      0.000   -9910.934   -3282.396
# ...

# %% [markdown]
# #### 나이가 증가함에 따라 의료비가 증가함을 확인할 수 있다.

# %% [markdown]
# ## 문제227. 비만이면 의료비가 더 지출되는지 확인하시오!

# %%
# 파생변수를 생성
# bmi가 30이상이면 1이고 아니면 0이다.

def func_1(x):
    if x >= 30:
        return 1
    else:
        return 0

df['bmi30'] = df['bmi'].apply(func_1)

# %%
import numpy as np
import statsmodels.api as sm
import statsmodels.formula.api as smf
import pandas as pd

df = pd.read_csv("d:\\data\\pandas\\insurance.csv", engine = 'python', encoding = 'cp949')
df['age2'] = df['age'] **2

def func_1(x):
    if x >= 30:
        return 1
    else:
        return 0

df['bmi30'] = df['bmi'].apply(func_1)

model = smf.ols(formula = 'expenses ~ age + sex + bmi + smoker + region + children + age2 + bmi30', data = df)
# 다중회귀분석시 더미변수화(문자 -> 숫자) 가 자동으로 진행된다.

result = model.fit()

print(result.summary(), '\n')
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:               expenses   R-squared:                       0.758
# Model:                            OLS   Adj. R-squared:                  0.756
# Method:                 Least Squares   F-statistic:                     416.2
# Date:                Tue, 11 Feb 2020   Prob (F-statistic):               0.00
# Time:                        16:01:43   Log-Likelihood:                -13528.
# No. Observations:                1338   AIC:                         2.708e+04
# Df Residuals:                    1327   BIC:                         2.713e+04
# Df Model:                          10
# Covariance Type:            nonrobust
# ...
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# Intercept           -2943.1758   1828.115     -1.610      0.108   -6529.486     643.134
# ...

# %% [markdown]
# ### 파생변수 age2추가 & bmi30 추가시
# ### 0.751 ---> 0.754 --> 0.758

# %% [markdown]
# ## 문제228. 비만이면서 흡연하는 사람이 의료비가 더 많이 드는지 확인하시오!

# %%
# bmi30 * smoker만 추가하면됨.
model = smf.ols(formula = 'expenses ~ age + sex + bmi + smoker + region + children + age2 + bmi30 + bmi30 * smoker', data = df)

# %%
import numpy as np
import statsmodels.api as sm
import statsmodels.formula.api as smf
import pandas as pd

df = pd.read_csv("d:\\data\\pandas\\insurance.csv", engine = 'python', encoding = 'cp949')
df['age2'] = df['age'] **2

def func_1(x):
    if x >= 30:
        return 1
    else:
        return 0

df['bmi30'] = df['bmi'].apply(func_1)

model = smf.ols(formula = 'expenses ~ age + sex + bmi + smoker + region + children + age2 + bmi30 + bmi30 * smoker', data = df)
# 다중회귀분석시 더미변수화(문자 -> 숫자) 가 자동으로 진행된다.

result = model.fit()

print(result.summary(), '\n')
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:               expenses   R-squared:                       0.866
# Model:                            OLS   Adj. R-squared:                  0.865
# Method:                 Least Squares   F-statistic:                     781.7
# Date:                Tue, 11 Feb 2020   Prob (F-statistic):               0.00
# Time:                        16:05:16   Log-Likelihood:                -13131.
# No. Observations:                1338   AIC:                         2.629e+04
# Df Residuals:                    1326   BIC:                         2.635e+04
# Df Model:                          11
# Covariance Type:            nonrobust
# ...
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# Intercept             134.2509   1362.751      0.099      0.922   -2539.132    2807.634
# ...

# %% [markdown]
# ### 어떤 파생변수를 생성해야하는가에 대한 회의가 매일매일 있음.

# %% [markdown]
# ## ■ 로지스틱 회귀 (logistic regression) 분석이란?
#
# 구글에서 로지스틱 회귀분석 위키피디아 해석!
#
# 로지스틱 회귀(영어: logistic regression)는 영국의 통계학자인 D. R. Cox가 1958년[1] 에 제안한 확률 모델로서 독립 변수의 선형 결합을 이용하여 사건의 발생 가능성을 예측하는데 사용되는 통계 기법이다.
#
# 로지스틱 회귀의 목적은 일반적인 회귀 분석의 목표와 동일하게
# 종속 변수와 독립 변수간의 관계를 구체적인 함수로 나타내어 향후 예측 모델에 사용하는 것이다.
#
# 이는 독립 변수의 선형 결합으로 종속 변수를 설명한다는 관점에서는 선형 회귀 분석과 유사하다.
# 하지만 로지스틱 회귀는 선형 회귀 분석과는 다르게 종속 변수가 범주형 데이터를 대상으로 하며 입력 데이터가 주어졌을 때
# 해당 데이터의 결과가 특정 분류로 나뉘기 때문에 __일종의 분류 (classification) 기법__으로도 볼 수 있다.

# %%
# 파이썬 모델 코드

from sklearn.linear_model import LogisticRegression
model = LogisticRegression(C = 1000, random_state = 0)
model.fit(X,y)

y_hat = model.predict(X_test)
print(y_hat)

# %% [markdown]
# ### ※ 설명 : C가 클수록 훈련 데이터에 정확도는 좋지만 오버피팅이 일어난다. 적절한 C를 찾는게 중요하다.

# %% [markdown]
# ### 문제229. 케글의 타이타닉 데이터의 모델을 로지스틱 회귀모델로 변경하여 수행하고 테스트 데이터의 score을 확인하시오~
#
# 1. knn
# 2. 나이브 베이즈
# 3. 의사결정트리
# 4. 랜덤포레스트 ---> 가장 정확도가 높음!
# 5. 로지스틱 회귀
